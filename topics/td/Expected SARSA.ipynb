# %%
% matplotlib inline

import matplotlib

from lib.envs.windy_gridworld import WindyGridworldEnv
from lib import plotting
from td_methods import expected_sarsa

matplotlib.style.use('ggplot')

# %%
env = WindyGridworldEnv()

# %%
Q, stats = expected_sarsa(env, 200)
# Out:
# Episode 100/200.
# Episode 200/200.

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x40e0710>,
#  <matplotlib.figure.Figure at 0x2e87ed0>,
#  <matplotlib.figure.Figure at 0x19e43eb0>)
