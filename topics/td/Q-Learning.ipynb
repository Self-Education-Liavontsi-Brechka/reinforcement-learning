# %%
% matplotlib inline

import matplotlib

from lib.envs.cliff_walking import CliffWalkingEnv
from lib import plotting
from td_methods import q_learning

matplotlib.style.use('ggplot')

# %%
env = CliffWalkingEnv()

# %%
Q, stats = q_learning(env, 500)
# Out:
# Episode 100/500.
# Episode 200/500.
# Episode 300/500.
# Episode 400/500.
# Episode 500/500.

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x19f71230>,
# ...
#  <matplotlib.figure.Figure at 0x1a1d1d90>)
