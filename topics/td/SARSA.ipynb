# %%
% matplotlib inline

import matplotlib

from lib.envs.windy_gridworld import WindyGridworldEnv
from lib import plotting
from td_methods import sarsa

matplotlib.style.use('ggplot')

# %%
env = WindyGridworldEnv()

# %%
Q, stats = sarsa(env, 200)
# Out:
# Episode 100/200.
# Episode 200/200.

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<matplotlib.figure.Figure at 0x4a385d0>,
#  <matplotlib.figure.Figure at 0x1a64cdf0>,
#  <matplotlib.figure.Figure at 0x1a5c1710>)
